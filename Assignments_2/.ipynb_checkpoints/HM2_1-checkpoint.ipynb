# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')


x_train = pd.read_csv('training_set.csv', header=None, names=['x1', 'x2', 'target'])
x_val = pd.read_csv('validation_set.csv', header=None, names=['x1', 'x2', 'target'])

x_train.plot.scatter('x1', 'x2', c='target')
x_val.plot.scatter('x1', 'x2', c='target')
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %%
# Preprocessing

x_train = pd.read_csv('training_set.csv', header=None, names=['x1', 'x2', 'target'])
x_val = pd.read_csv('validation_set.csv', header=None, names=['x1', 'x2', 'target'])

x_train['x1'] = (x_train['x1'] - x_train['x1'].mean())/x_train['x1'].std()
x_train['x2'] = (x_train['x2'] - x_train['x2'].mean())/x_train['x2'].std()

x_val['x1'] = (x_val['x1'] - x_val['x1'].mean())/x_val['x1'].std()
x_val['x2'] = (x_val['x2'] - x_val['x2'].mean())/x_val['x2'].std()

x_train.plot.scatter('x1', 'x2', c='target')
x_val.plot.scatter('x1', 'x2', c='target')
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %%
# Network layout
# 2 inputs - M hidden neurons - one output

def g_prime(a: float) -> float:
    return 1/(np.cosh(a)**2)



class Network:
    def __init__(self, M):
        self.M = M # Number of neurons
        self.w = np.random.normal(0,1,(M, 2)) # Hidden layer
        self.th = np.random.normal(0,1,(M, )) # Hidden layer
        self.W = np.random.normal(0,1,(M,  )) # Output layer
        self.T = np.random.normal(0,1)        # Output layer
        self.lr = 0.001                       # learning rate
        self.pval = 5000
        self.ptrain = 10000
        self.iteration = 0
        self.c_errors = []
        # g = tanh(x)
        # g' = sech^2(x) = 1 - tanh^2
        
        
    def feed_forward(self, x : list) -> float: 
        # Hidden layer
        b = self.w @ x - self.th
        V = np.tanh(b)
        # Output layer
        B = np.dot(self.W, V) - self.T
        O = np.tanh(B)
        
        return b, V, B, O
    
    def train_deterministic(self, x_train, x_val, num_epochs=1):
        # Train until C < 12%
        # Save WW, w, T, th
        
        for _ in range(num_epochs):
            bp_vals = []
            outputs = []
            # Feed all patterns 
            for index, row in x_train.iterrows():
                x_i = [row['x1'], row['x2']]

                # Feed pattern
                bp = self.feed_forward(x_i) # order: b, V, B, O
                bp_vals.append(bp)
                outputs.append(bp[-1]) # order will align with x_train
                
            x_train['O'] = bp_vals
                
            # Backpropagation
            dw = np.zeros((self.M, 2))
            dW = np.zeros((self.M,))
            dth = np.zeros((self.M,))
            dT = 0
            for index, row in x_train.iterrows():
                x_i = [row['x1'], row['x2']]
                #print(x_i.shape)
                t = row['target']
                b, V, B, O = row['O']

                g = (t - O) * g_prime(B) # gamma
                d = g * np.multiply(self.W, g_prime(b))  # delta
                dW += g * V
                dT += g
                dw += np.outer(d, x_i)
                dth += d

            self.W += self.lr * dW
            self.T -= self.lr * dT
            self.w += self.lr * dw
            self.th -= self.lr * dth
        
            c_error = self.validate(x_val)
            self.c_errors.append(c_error)
        
            if c_error > 0.12:
                # If 5 latest c_errors are identical
    #             if self.iteration > 20 and c_error - np.sum(self.c_errors[-5:])/5 < 0.01:
    #                 print(f'Steady point with c_error={c_error:.4f} found after {self.iteration + 1 : >2} iterations')
    #                 return -1


                print(f'iter: {self.iteration: >3}\tc_error {c_error: >2}')
                self.iteration += 1
    #             self.train_deterministic(x_train, x_val)
    
    def train_stochastic(self, x_train : pd.DataFrame, x_val : pd.DataFrame):
        
        # Choose 1 random patterns
        # feed
        # backpropagate
        # validate every 10 patterns
        # repeat
        run = 1
        while run: 
            for _ in range(self.ptrain):
                idx = np.random.choice(self.ptrain)
                # Minibatching for speed
                row = x_train.iloc[idx]

                x = [row['x1'], row['x2']]
                t = row['target']

                b, V, B, O = self.feed_forward(x)

                # backpropagate
                g = (t - O) * g_prime(np.dot(self.W, V) - self.T)
                d = g * self.W * g_prime(self.w @ x - self.th)

                dW = g * V
                dT = g

                dw = np.outer(d, x)
                dth = d 

                self.W += self.lr * dW
                self.T -= self.lr * dT
                self.w += self.lr * dw
                self.th -= self.lr * dth

            # Validate
            c_error = self.validate(x_val)
            self.c_errors.append(c_error)
            
            if c_error > 0.118:
                print(f'iter: {self.iteration: >3}\tc_error {c_error}')
                self.iteration += 1
                # If 5 latest c_errors are identical
                if self.iteration > 2000:
                    self.iteration = 0
                    run = 0
            else:
                print(f'Found c_error lower than 0.12: c_error = {c_error}, iter: {self.iteration}')
                run = 0
                
                
                
    def classification_error(self, targets: list, predictions: list) -> float:
        
        c_error = 0
        
        O_sgn = np.sign(predictions)
        O_sgn[O_sgn == 0] = 1
        
        e_abs = np.abs(O_sgn - targets)
        c_error = np.sum(e_abs)/(2*self.pval)
        
        
        
        return c_error
    
    
    def validate(self, x_val):
        
        targets = list(x_val['target'])
        preds = []
        
        for index, row in x_val.iterrows():
            x_i = [row['x1'], row['x2']]
            preds.append(self.feed_forward(x_i)[-1])
        
        c_error = self.classification_error(list(x_val['target']), preds)
        
        return c_error
    
    

#a = Network(1024)

# %%
# x_val = pd.read_csv('validation_set.csv', header=None, names=['x1', 'x2', 'target'])
# a.train(x_train)
a.train_deterministic(x_train, x_val)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_19656\4188593126.py:5: RuntimeWarning: overflow encountered in double_scalars
#   return 1/(np.cosh(a)**2)
# C:\Users\admin\AppData\Local\Temp\ipykernel_19656\4188593126.py:5: RuntimeWarning: overflow encountered in cosh
#   return 1/(np.cosh(a)**2)
# iter:   0	c_error 0.3396
# iter:   1	c_error 0.3378
# iter:   2	c_error 0.3346
# iter:   3	c_error 0.3328
# iter:   4	c_error 0.3304
# iter:   5	c_error 0.3256
# iter:   6	c_error 0.3252
# iter:   7	c_error 0.323
# iter:   8	c_error 0.3206
# iter:   9	c_error 0.317
# iter:  10	c_error 0.3148
# iter:  11	c_error 0.3106
# iter:  12	c_error 0.3086
# iter:  13	c_error 0.3042
# iter:  14	c_error 0.3022
# iter:  15	c_error 0.2998
# iter:  16	c_error 0.2986
# iter:  17	c_error 0.2942
# iter:  18	c_error 0.2916
# iter:  19	c_error 0.2874
# iter:  20	c_error 0.2854
# iter:  21	c_error 0.2796
# iter:  22	c_error 0.2762
# iter:  23	c_error 0.2736
# iter:  24	c_error 0.269
# iter:  25	c_error 0.2626
# iter:  26	c_error 0.2604
# iter:  27	c_error 0.2546
# iter:  28	c_error 0.25
# iter:  29	c_error 0.2496
# iter:  30	c_error 0.2488
# iter:  31	c_error 0.2454
# iter:  32	c_error 0.243
# iter:  33	c_error 0.2414
# iter:  34	c_error 0.2356
# iter:  35	c_error 0.2324
# iter:  36	c_error 0.2306
# iter:  37	c_error 0.2294
# iter:  38	c_error 0.227
# iter:  39	c_error 0.223
# iter:  40	c_error 0.219
# iter:  41	c_error 0.2168
# iter:  42	c_error 0.2154
# iter:  43	c_error 0.213
# iter:  44	c_error 0.2102
# iter:  45	c_error 0.206
# iter:  46	c_error 0.2028
# iter:  47	c_error 0.1964
# iter:  48	c_error 0.1932
# iter:  49	c_error 0.1874
# iter:  50	c_error 0.1814
# iter:  51	c_error 0.1748
# iter:  52	c_error 0.173
# iter:  53	c_error 0.1678
# iter:  54	c_error 0.1654
# iter:  55	c_error 0.163
# iter:  56	c_error 0.1608
# iter:  57	c_error 0.1596
# iter:  58	c_error 0.1542
# iter:  59	c_error 0.1536
# iter:  60	c_error 0.153
# iter:  61	c_error 0.1526
# iter:  62	c_error 0.1518
# iter:  63	c_error 0.1518
# iter:  64	c_error 0.1518
# iter:  65	c_error 0.1516
# iter:  66	c_error 0.1516
# iter:  67	c_error 0.1516
# iter:  68	c_error 0.1516
# iter:  69	c_error 0.1516
# iter:  70	c_error 0.1516
# iter:  71	c_error 0.1516
# iter:  72	c_error 0.1516
# iter:  73	c_error 0.1516
# iter:  74	c_error 0.1516
# iter:  75	c_error 0.1516
# iter:  76	c_error 0.1516
# iter:  77	c_error 0.1516
# iter:  78	c_error 0.1516
# iter:  79	c_error 0.1516
# iter:  80	c_error 0.1516
# iter:  81	c_error 0.1516
# iter:  82	c_error 0.1516
# iter:  83	c_error 0.1516
# iter:  84	c_error 0.1516
# iter:  85	c_error 0.1516
# iter:  86	c_error 0.1516
# iter:  87	c_error 0.1516
# iter:  88	c_error 0.1516
# iter:  89	c_error 0.1516
# iter:  90	c_error 0.1516
# iter:  91	c_error 0.1516
# iter:  92	c_error 0.1516
# iter:  93	c_error 0.1516
# iter:  94	c_error 0.1516
# iter:  95	c_error 0.1516
# iter:  96	c_error 0.1516
# iter:  97	c_error 0.1516
# iter:  98	c_error 0.1516
# iter:  99	c_error 0.1516
# iter: 100	c_error 0.1516
# iter: 101	c_error 0.1516
# iter: 102	c_error 0.1516
# iter: 103	c_error 0.1516
# iter: 104	c_error 0.1516
# iter: 105	c_error 0.1516
# iter: 106	c_error 0.1516
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [44], line 3
#       1 # x_val = pd.read_csv('validation_set.csv', header=None, names=['x1', 'x2', 'target'])
#       2 # a.train(x_train)
# ----> 3 a.train_deterministic(x_train, x_val, 500)
#
# Cell In [43], line 65, in Network.train_deterministic(self, x_train, x_val, num_epochs)
#      62 b, V, B, O = row['O']
#      64 g = (t - O) * g_prime(B) # gamma
# ---> 65 d = g * np.multiply(self.W, g_prime(b))  # delta
#      66 dW += g * V
#      67 dT += g
#
# Cell In [43], line 5, in g_prime(a)
#       4 def g_prime(a: float) -> float:
# ----> 5     return 1/(np.cosh(a)**2)
#
# KeyboardInterrupt:

# %%
# b = Network(20)
# b.lr = 0.005
# Testa lr 0.0025
b.w = w
b.W = W
b.th = th
b.T = T
b.train_stochastic(x_train, x_val)
# tmp = a.c_errors[-6:]
# print(tmp)

# tmp[tmp==0.1516] = -1
# print(tmp)
# Out:
# iter:  10	c_error 0.1218
# iter:  11	c_error 0.1218
# iter:  12	c_error 0.1206
# iter:  13	c_error 0.121
# iter:  14	c_error 0.1214
# iter:  15	c_error 0.1192
# iter:  16	c_error 0.1218
# iter:  17	c_error 0.1186
# iter:  18	c_error 0.1216
# iter:  19	c_error 0.1198
# iter:  20	c_error 0.122
# iter:  21	c_error 0.1188
# iter:  22	c_error 0.122
# iter:  23	c_error 0.1224
# iter:  24	c_error 0.1186
# iter:  25	c_error 0.1196
# iter:  26	c_error 0.1208
# iter:  27	c_error 0.1192
# iter:  28	c_error 0.1202
# iter:  29	c_error 0.1198
# iter:  30	c_error 0.1176
# iter:  31	c_error 0.1236
# iter:  32	c_error 0.1208
# iter:  33	c_error 0.1208
# iter:  34	c_error 0.1232
# iter:  35	c_error 0.1188
# iter:  36	c_error 0.12
# iter:  37	c_error 0.1206
# iter:  38	c_error 0.1186
# iter:  39	c_error 0.122
# iter:  40	c_error 0.12
# iter:  41	c_error 0.1216
# iter:  42	c_error 0.1226
# iter:  43	c_error 0.119
# iter:  44	c_error 0.1186
# iter:  45	c_error 0.1208
# iter:  46	c_error 0.1226
# iter:  47	c_error 0.1182
# iter:  48	c_error 0.12
# iter:  49	c_error 0.1226
# iter:  50	c_error 0.1194
# iter:  51	c_error 0.1182
# iter:  52	c_error 0.122
# iter:  53	c_error 0.1204
# iter:  54	c_error 0.12
# iter:  55	c_error 0.1238
# iter:  56	c_error 0.119
# iter:  57	c_error 0.1196
# iter:  58	c_error 0.1188
# iter:  59	c_error 0.1212
# iter:  60	c_error 0.1166
# iter:  61	c_error 0.1222
# iter:  62	c_error 0.1216
# iter:  63	c_error 0.1192
# iter:  64	c_error 0.122
# iter:  65	c_error 0.1196
# iter:  66	c_error 0.1194
# iter:  67	c_error 0.118
# iter:  68	c_error 0.1212
# iter:  69	c_error 0.1208
# iter:  70	c_error 0.1248
# iter:  71	c_error 0.1212
# iter:  72	c_error 0.121
# iter:  73	c_error 0.1194
# iter:  74	c_error 0.1206
# iter:  75	c_error 0.1244
# iter:  76	c_error 0.121
# iter:  77	c_error 0.1172
# iter:  78	c_error 0.1202
# iter:  79	c_error 0.1224
# iter:  80	c_error 0.126
# iter:  81	c_error 0.1194
# iter:  82	c_error 0.1202
# iter:  83	c_error 0.1206
# iter:  84	c_error 0.1214
# iter:  85	c_error 0.1194
# iter:  86	c_error 0.1206
# iter:  87	c_error 0.1234
# iter:  88	c_error 0.1196
# iter:  89	c_error 0.122
# iter:  90	c_error 0.1212
# iter:  91	c_error 0.1202
# iter:  92	c_error 0.12
# iter:  93	c_error 0.1202
# iter:  94	c_error 0.1176
# iter:  95	c_error 0.1196
# iter:  96	c_error 0.1186
# iter:  97	c_error 0.1188
# iter:  98	c_error 0.12
# iter:  99	c_error 0.1188
# iter: 100	c_error 0.1212
# iter: 1080	c_error 0.1236
# iter: 1081	c_error 0.117
# iter: 1082	c_error 0.1174
# iter: 1083	c_error 0.1218
# iter: 1084	c_error 0.119
# iter: 1085	c_error 0.119
# iter: 1086	c_error 0.118
# iter: 1087	c_error 0.1178
# iter: 1088	c_error 0.1218
# iter: 1089	c_error 0.1194
# iter: 1090	c_error 0.1252
# iter: 1091	c_error 0.1204
# iter: 1092	c_error 0.1212
# iter: 1093	c_error 0.1196
# iter: 1094	c_error 0.1208
# iter: 1095	c_error 0.1194
# iter: 1096	c_error 0.1204
# iter: 1097	c_error 0.1174
# iter: 1098	c_error 0.1202
# iter: 1099	c_error 0.1204
# iter: 1100	c_error 0.1232
# iter: 1101	c_error 0.1196
# iter: 1102	c_error 0.1184
# iter: 1103	c_error 0.1212
# iter: 1104	c_error 0.12
# iter: 1105	c_error 0.1198
# iter: 1106	c_error 0.1184
# iter: 1107	c_error 0.1204
# iter: 1108	c_error 0.1212
# iter: 1109	c_error 0.1264
# iter: 1110	c_error 0.1194
# iter: 1111	c_error 0.132
# iter: 1112	c_error 0.119
# iter: 1113	c_error 0.126
# iter: 1114	c_error 0.1178
# iter: 1115	c_error 0.1196
# iter: 1116	c_error 0.1208
# iter: 1117	c_error 0.1196
# iter: 1118	c_error 0.124
# iter: 1119	c_error 0.1192
# iter: 1120	c_error 0.1228
# iter: 1121	c_error 0.1212
# iter: 1122	c_error 0.1216
# iter: 1123	c_error 0.118
# iter: 1124	c_error 0.1178
# iter: 1125	c_error 0.1198
# iter: 1126	c_error 0.1218
# iter: 1127	c_error 0.1184
# iter: 1128	c_error 0.1168
# iter: 1129	c_error 0.1196
# iter: 1130	c_error 0.1212
# iter: 1131	c_error 0.1218
# iter: 1132	c_error 0.1206
# iter: 1133	c_error 0.12
# iter: 1134	c_error 0.1218
# iter: 1135	c_error 0.1192
# iter: 1136	c_error 0.118
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [64], line 8
#       6 b.th = th
#       7 b.T = T
# ----> 8 b.train_stochastic(x_train, x_val)
#
# Cell In [59], line 125, in Network.train_stochastic(self, x_train, x_val)
#     122     self.th -= self.lr * dth
#     124 # Validate
# --> 125 c_error = self.validate(x_val)
#     126 self.c_errors.append(c_error)
#     128 if c_error > 0.116:
#
# Cell In [59], line 163, in Network.validate(self, x_val)
#     161 for index, row in x_val.iterrows():
#     162     x_i = [row['x1'], row['x2']]
# --> 163     preds.append(self.feed_forward(x_i)[-1])
#     165 c_error = self.classification_error(list(x_val['target']), preds)
#     167 return c_error
#
# Cell In [59], line 30, in Network.feed_forward(self, x)
#      28 V = np.tanh(b)
#      29 # Output layer
# ---> 30 B = np.dot(self.W, V) - self.T
#      31 O = np.tanh(B)
#      33 return b, V, B, O
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
w = b.w
W = b.W
th = b.th
T = b.T

# %%
# w_df = pd.DataFrame(w)
w_df.to_csv('w1.csv', header=False, index=False)
W_df = pd.DataFrame(W)
W_df.to_csv('w2.csv', header=False, index=False)
th_df = pd.DataFrame(th)
T_df = pd.DataFrame([T])
th_df.to_csv('t1.csv', header=False, index=False)

T_df.to_csv('t2.csv', header=False, index=False)
